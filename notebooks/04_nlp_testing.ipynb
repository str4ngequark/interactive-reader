# %% [markdown]
# # NLP Pipeline Testing
#
# Test the formatting pipeline before integrating it into the Streamlit app.

# %%
import sys
sys.path.append('..')

from src import NLPProcessor
import json

processor = NLPProcessor()

with open('../data/fragments.json', 'r', encoding='utf-8') as f:
    sections = json.load(f)
# Out:
# Loading weights: 100%|████████████████████| 258/258 [00:00<00:00, 67325.98it/s]

# %%
test_text = '\n\n'.join(sections['1']['paragraphs'])
formatted = processor.format_section(sections['1']['paragraphs'])

print("=== FORMATTED OUTPUT ===\n")
print(formatted[:1500])
# Out:
# === FORMATTED OUTPUT ===
#
# ...
